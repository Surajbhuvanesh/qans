# %%
from math import*
def euclidean_distance(x,y):
    return sqrt(sum(pow(a-b,2) for a, b in zip(x, y)))
euclidean_distance([0,3,4,5],[7,6,3,-1])
# Out:
# 9.746794344808963

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import Imputer
from sklearn.cross_validation import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
cancer_data = np.genfromtxt(fname ='breast-cancer-wisconsin-data.csv', delimiter= ',', dtype= float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-ef6c8bbce15f> in <module>()
# ----> 1 cancer_data = np.genfromtxt(fname ='breast-cancer-wisconsin-data.csv', delimiter= ',', dtype= float)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2017             # Raise an exception ?
#    2018             if invalid_raise:
# -> 2019                 raise ValueError(errmsg)
#    2020             # Issue a warning ?
#    2021             else:
#
# ValueError: Some errors were detected !
#     Line #2 (got 32 columns instead of 33)
#     Line #3 (got 32 columns instead of 33)
#     Line #4 (got 32 columns instead of 33)
#     Line #5 (got 32 columns instead of 33)
#     Line #6 (got 32 columns instead of 33)
#     Line #7 (got 32 columns instead of 33)
#     Line #8 (got 32 columns instead of 33)
#     Line #9 (got 32 columns instead of 33)
#     Line #10 (got 32 columns instead of 33)
#     Line #11 (got 32 columns instead of 33)
#     Line #12 (got 32 columns instead of 33)
#     Line #13 (got 32 columns instead of 33)
#     Line #14 (got 32 columns instead of 33)
#     Line #15 (got 32 columns instead of 33)
#     Line #16 (got 32 columns instead of 33)
#     Line #17 (got 32 columns instead of 33)
#     Line #18 (got 32 columns instead of 33)
#     Line #19 (got 32 columns instead of 33)
#     Line #20 (got 32 columns instead of 33)
#     Line #21 (got 32 columns instead of 33)
#     Line #22 (got 32 columns instead of 33)
#     Line #23 (got 32 columns instead of 33)
#     Line #24 (got 32 columns instead of 33)
#     Line #25 (got 32 columns instead of 33)
#     Line #26 (got 32 columns instead of 33)
#     Line #27 (got 32 columns instead of 33)
#     Line #28 (got 32 columns instead of 33)
#     Line #29 (got 32 columns instead of 33)
#     Line #30 (got 32 columns instead of 33)
#     Line #31 (got 32 columns instead of 33)
#     Line #32 (got 32 columns instead of 33)
#     Line #33 (got 32 columns instead of 33)
#     Line #34 (got 32 columns instead of 33)
#     Line #35 (got 32 columns instead of 33)
#     Line #36 (got 32 columns instead of 33)
#     Line #37 (got 32 columns instead of 33)
#     Line #38 (got 32 columns instead of 33)
#     Line #39 (got 32 columns instead of 33)
#     Line #40 (got 32 columns instead of 33)
#     Line #41 (got 32 columns instead of 33)
#     Line #42 (got 32 columns instead of 33)
#     Line #43 (got 32 columns instead of 33)
#     Line #44 (got 32 columns instead of 33)
#     Line #45 (got 32 columns instead of 33)
#     Line #46 (got 32 columns instead of 33)
#     Line #47 (got 32 columns instead of 33)
#     Line #48 (got 32 columns instead of 33)
#     Line #49 (got 32 columns instead of 33)
#     Line #50 (got 32 columns instead of 33)
#     Line #51 (got 32 columns instead of 33)
#     Line #52 (got 32 columns instead of 33)
#     Line #53 (got 32 columns instead of 33)
#     Line #54 (got 32 columns instead of 33)
#     Line #55 (got 32 columns instead of 33)
#     Line #56 (got 32 columns instead of 33)
#     Line #57 (got 32 columns instead of 33)
#     Line #58 (got 32 columns instead of 33)
#     Line #59 (got 32 columns instead of 33)
#     Line #60 (got 32 columns instead of 33)
#     Line #61 (got 32 columns instead of 33)
#     Line #62 (got 32 columns instead of 33)
#     Line #63 (got 32 columns instead of 33)
#     Line #64 (got 32 columns instead of 33)
#     Line #65 (got 32 columns instead of 33)
#     Line #66 (got 32 columns instead of 33)
#     Line #67 (got 32 columns instead of 33)
#     Line #68 (got 32 columns instead of 33)
#     Line #69 (got 32 columns instead of 33)
#     Line #70 (got 32 columns instead of 33)
#     Line #71 (got 32 columns instead of 33)
#     Line #72 (got 32 columns instead of 33)
#     Line #73 (got 32 columns instead of 33)
#     Line #74 (got 32 columns instead of 33)
#     Line #75 (got 32 columns instead of 33)
#     Line #76 (got 32 columns instead of 33)
#     Line #77 (got 32 columns instead of 33)
#     Line #78 (got 32 columns instead of 33)
#     Line #79 (got 32 columns instead of 33)
#     Line #80 (got 32 columns instead of 33)
#     Line #81 (got 32 columns instead of 33)
#     Line #82 (got 32 columns instead of 33)
#     Line #83 (got 32 columns instead of 33)
#     Line #84 (got 32 columns instead of 33)
#     Line #85 (got 32 columns instead of 33)
#     Line #86 (got 32 columns instead of 33)
#     Line #87 (got 32 columns instead of 33)
#     Line #88 (got 32 columns instead of 33)
#     Line #89 (got 32 columns instead of 33)
#     Line #90 (got 32 columns instead of 33)
#     Line #91 (got 32 columns instead of 33)
#     Line #92 (got 32 columns instead of 33)
#     Line #93 (got 32 columns instead of 33)
#     Line #94 (got 32 columns instead of 33)
#     Line #95 (got 32 columns instead of 33)
#     Line #96 (got 32 columns instead of 33)
#     Line #97 (got 32 columns instead of 33)
#     Line #98 (got 32 columns instead of 33)
#     Line #99 (got 32 columns instead of 33)
#     Line #100 (got 32 columns instead of 33)
#     Line #101 (got 32 columns instead of 33)
#     Line #102 (got 32 columns instead of 33)
#     Line #103 (got 32 columns instead of 33)
#     Line #104 (got 32 columns instead of 33)
#     Line #105 (got 32 columns instead of 33)
#     Line #106 (got 32 columns instead of 33)
#     Line #107 (got 32 columns instead of 33)
#     Line #108 (got 32 columns instead of 33)
#     Line #109 (got 32 columns instead of 33)
#     Line #110 (got 32 columns instead of 33)
#     Line #111 (got 32 columns instead of 33)
#     Line #112 (got 32 columns instead of 33)
#     Line #113 (got 32 columns instead of 33)
#     Line #114 (got 32 columns instead of 33)
#     Line #115 (got 32 columns instead of 33)
#     Line #116 (got 32 columns instead of 33)
#     Line #117 (got 32 columns instead of 33)
#     Line #118 (got 32 columns instead of 33)
#     Line #119 (got 32 columns instead of 33)
#     Line #120 (got 32 columns instead of 33)
#     Line #121 (got 32 columns instead of 33)
#     Line #122 (got 32 columns instead of 33)
#     Line #123 (got 32 columns instead of 33)
#     Line #124 (got 32 columns instead of 33)
#     Line #125 (got 32 columns instead of 33)
#     Line #126 (got 32 columns instead of 33)
#     Line #127 (got 32 columns instead of 33)
#     Line #128 (got 32 columns instead of 33)
#     Line #129 (got 32 columns instead of 33)
#     Line #130 (got 32 columns instead of 33)
#     Line #131 (got 32 columns instead of 33)
#     Line #132 (got 32 columns instead of 33)
#     Line #133 (got 32 columns instead of 33)
#     Line #134 (got 32 columns instead of 33)
#     Line #135 (got 32 columns instead of 33)
#     Line #136 (got 32 columns instead of 33)
#     Line #137 (got 32 columns instead of 33)
#     Line #138 (got 32 columns instead of 33)
#     Line #139 (got 32 columns instead of 33)
#     Line #140 (got 32 columns instead of 33)
#     Line #141 (got 32 columns instead of 33)
#     Line #142 (got 32 columns instead of 33)
#     Line #143 (got 32 columns instead of 33)
#     Line #144 (got 32 columns instead of 33)
#     Line #145 (got 32 columns instead of 33)
#     Line #146 (got 32 columns instead of 33)
#     Line #147 (got 32 columns instead of 33)
#     Line #148 (got 32 columns instead of 33)
#     Line #149 (got 32 columns instead of 33)
#     Line #150 (got 32 columns instead of 33)
#     Line #151 (got 32 columns instead of 33)
#     Line #152 (got 32 columns instead of 33)
#     Line #153 (got 32 columns instead of 33)
#     Line #154 (got 32 columns instead of 33)
#     Line #155 (got 32 columns instead of 33)
#     Line #156 (got 32 columns instead of 33)
#     Line #157 (got 32 columns instead of 33)
#     Line #158 (got 32 columns instead of 33)
#     Line #159 (got 32 columns instead of 33)
#     Line #160 (got 32 columns instead of 33)
#     Line #161 (got 32 columns instead of 33)
#     Line #162 (got 32 columns instead of 33)
#     Line #163 (got 32 columns instead of 33)
#     Line #164 (got 32 columns instead of 33)
#     Line #165 (got 32 columns instead of 33)
#     Line #166 (got 32 columns instead of 33)
#     Line #167 (got 32 columns instead of 33)
#     Line #168 (got 32 columns instead of 33)
#     Line #169 (got 32 columns instead of 33)
#     Line #170 (got 32 columns instead of 33)
#     Line #171 (got 32 columns instead of 33)
#     Line #172 (got 32 columns instead of 33)
#     Line #173 (got 32 columns instead of 33)
#     Line #174 (got 32 columns instead of 33)
#     Line #175 (got 32 columns instead of 33)
#     Line #176 (got 32 columns instead of 33)
#     Line #177 (got 32 columns instead of 33)
#     Line #178 (got 32 columns instead of 33)
#     Line #179 (got 32 columns instead of 33)
#     Line #180 (got 32 columns instead of 33)
#     Line #181 (got 32 columns instead of 33)
#     Line #182 (got 32 columns instead of 33)
#     Line #183 (got 32 columns instead of 33)
#     Line #184 (got 32 columns instead of 33)
#     Line #185 (got 32 columns instead of 33)
#     Line #186 (got 32 columns instead of 33)
#     Line #187 (got 32 columns instead of 33)
#     Line #188 (got 32 columns instead of 33)
#     Line #189 (got 32 columns instead of 33)
#     Line #190 (got 32 columns instead of 33)
#     Line #191 (got 32 columns instead of 33)
#     Line #192 (got 32 columns instead of 33)
#     Line #193 (got 32 columns instead of 33)
#     Line #194 (got 32 columns instead of 33)
#     Line #195 (got 32 columns instead of 33)
#     Line #196 (got 32 columns instead of 33)
#     Line #197 (got 32 columns instead of 33)
#     Line #198 (got 32 columns instead of 33)
#     Line #199 (got 32 columns instead of 33)
#     Line #200 (got 32 columns instead of 33)
#     Line #201 (got 32 columns instead of 33)
#     Line #202 (got 32 columns instead of 33)
#     Line #203 (got 32 columns instead of 33)
#     Line #204 (got 32 columns instead of 33)
#     Line #205 (got 32 columns instead of 33)
#     Line #206 (got 32 columns instead of 33)
#     Line #207 (got 32 columns instead of 33)
#     Line #208 (got 32 columns instead of 33)
#     Line #209 (got 32 columns instead of 33)
#     Line #210 (got 32 columns instead of 33)
#     Line #211 (got 32 columns instead of 33)
#     Line #212 (got 32 columns instead of 33)
#     Line #213 (got 32 columns instead of 33)
#     Line #214 (got 32 columns instead of 33)
#     Line #215 (got 32 columns instead of 33)
#     Line #216 (got 32 columns instead of 33)
#     Line #217 (got 32 columns instead of 33)
#     Line #218 (got 32 columns instead of 33)
#     Line #219 (got 32 columns instead of 33)
#     Line #220 (got 32 columns instead of 33)
#     Line #221 (got 32 columns instead of 33)
#     Line #222 (got 32 columns instead of 33)
#     Line #223 (got 32 columns instead of 33)
#     Line #224 (got 32 columns instead of 33)
#     Line #225 (got 32 columns instead of 33)
#     Line #226 (got 32 columns instead of 33)
#     Line #227 (got 32 columns instead of 33)
#     Line #228 (got 32 columns instead of 33)
#     Line #229 (got 32 columns instead of 33)
#     Line #230 (got 32 columns instead of 33)
#     Line #231 (got 32 columns instead of 33)
#     Line #232 (got 32 columns instead of 33)
#     Line #233 (got 32 columns instead of 33)
#     Line #234 (got 32 columns instead of 33)
#     Line #235 (got 32 columns instead of 33)
#     Line #236 (got 32 columns instead of 33)
#     Line #237 (got 32 columns instead of 33)
#     Line #238 (got 32 columns instead of 33)
#     Line #239 (got 32 columns instead of 33)
#     Line #240 (got 32 columns instead of 33)
#     Line #241 (got 32 columns instead of 33)
#     Line #242 (got 32 columns instead of 33)
#     Line #243 (got 32 columns instead of 33)
#     Line #244 (got 32 columns instead of 33)
#     Line #245 (got 32 columns instead of 33)
#     Line #246 (got 32 columns instead of 33)
#     Line #247 (got 32 columns instead of 33)
#     Line #248 (got 32 columns instead of 33)
#     Line #249 (got 32 columns instead of 33)
#     Line #250 (got 32 columns instead of 33)
#     Line #251 (got 32 columns instead of 33)
#     Line #252 (got 32 columns instead of 33)
#     Line #253 (got 32 columns instead of 33)
#     Line #254 (got 32 columns instead of 33)
#     Line #255 (got 32 columns instead of 33)
#     Line #256 (got 32 columns instead of 33)
#     Line #257 (got 32 columns instead of 33)
#     Line #258 (got 32 columns instead of 33)
#     Line #259 (got 32 columns instead of 33)
#     Line #260 (got 32 columns instead of 33)
#     Line #261 (got 32 columns instead of 33)
#     Line #262 (got 32 columns instead of 33)
#     Line #263 (got 32 columns instead of 33)
#     Line #264 (got 32 columns instead of 33)
#     Line #265 (got 32 columns instead of 33)
#     Line #266 (got 32 columns instead of 33)
#     Line #267 (got 32 columns instead of 33)
#     Line #268 (got 32 columns instead of 33)
#     Line #269 (got 32 columns instead of 33)
#     Line #270 (got 32 columns instead of 33)
#     Line #271 (got 32 columns instead of 33)
#     Line #272 (got 32 columns instead of 33)
#     Line #273 (got 32 columns instead of 33)
#     Line #274 (got 32 columns instead of 33)
#     Line #275 (got 32 columns instead of 33)
#     Line #276 (got 32 columns instead of 33)
#     Line #277 (got 32 columns instead of 33)
#     Line #278 (got 32 columns instead of 33)
#     Line #279 (got 32 columns instead of 33)
#     Line #280 (got 32 columns instead of 33)
#     Line #281 (got 32 columns instead of 33)
#     Line #282 (got 32 columns instead of 33)
#     Line #283 (got 32 columns instead of 33)
#     Line #284 (got 32 columns instead of 33)
#     Line #285 (got 32 columns instead of 33)
#     Line #286 (got 32 columns instead of 33)
#     Line #287 (got 32 columns instead of 33)
#     Line #288 (got 32 columns instead of 33)
#     Line #289 (got 32 columns instead of 33)
#     Line #290 (got 32 columns instead of 33)
#     Line #291 (got 32 columns instead of 33)
#     Line #292 (got 32 columns instead of 33)
#     Line #293 (got 32 columns instead of 33)
#     Line #294 (got 32 columns instead of 33)
#     Line #295 (got 32 columns instead of 33)
#     Line #296 (got 32 columns instead of 33)
#     Line #297 (got 32 columns instead of 33)
#     Line #298 (got 32 columns instead of 33)
#     Line #299 (got 32 columns instead of 33)
#     Line #300 (got 32 columns instead of 33)
#     Line #301 (got 32 columns instead of 33)
#     Line #302 (got 32 columns instead of 33)
#     Line #303 (got 32 columns instead of 33)
#     Line #304 (got 32 columns instead of 33)
#     Line #305 (got 32 columns instead of 33)
#     Line #306 (got 32 columns instead of 33)
#     Line #307 (got 32 columns instead of 33)
#     Line #308 (got 32 columns instead of 33)
#     Line #309 (got 32 columns instead of 33)
#     Line #310 (got 32 columns instead of 33)
#     Line #311 (got 32 columns instead of 33)
#     Line #312 (got 32 columns instead of 33)
#     Line #313 (got 32 columns instead of 33)
#     Line #314 (got 32 columns instead of 33)
#     Line #315 (got 32 columns instead of 33)
#     Line #316 (got 32 columns instead of 33)
#     Line #317 (got 32 columns instead of 33)
#     Line #318 (got 32 columns instead of 33)
#     Line #319 (got 32 columns instead of 33)
#     Line #320 (got 32 columns instead of 33)
#     Line #321 (got 32 columns instead of 33)
#     Line #322 (got 32 columns instead of 33)
#     Line #323 (got 32 columns instead of 33)
#     Line #324 (got 32 columns instead of 33)
#     Line #325 (got 32 columns instead of 33)
#     Line #326 (got 32 columns instead of 33)
#     Line #327 (got 32 columns instead of 33)
#     Line #328 (got 32 columns instead of 33)
#     Line #329 (got 32 columns instead of 33)
#     Line #330 (got 32 columns instead of 33)
#     Line #331 (got 32 columns instead of 33)
#     Line #332 (got 32 columns instead of 33)
#     Line #333 (got 32 columns instead of 33)
#     Line #334 (got 32 columns instead of 33)
#     Line #335 (got 32 columns instead of 33)
#     Line #336 (got 32 columns instead of 33)
#     Line #337 (got 32 columns instead of 33)
#     Line #338 (got 32 columns instead of 33)
#     Line #339 (got 32 columns instead of 33)
#     Line #340 (got 32 columns instead of 33)
#     Line #341 (got 32 columns instead of 33)
#     Line #342 (got 32 columns instead of 33)
#     Line #343 (got 32 columns instead of 33)
#     Line #344 (got 32 columns instead of 33)
#     Line #345 (got 32 columns instead of 33)
#     Line #346 (got 32 columns instead of 33)
#     Line #347 (got 32 columns instead of 33)
#     Line #348 (got 32 columns instead of 33)
#     Line #349 (got 32 columns instead of 33)
#     Line #350 (got 32 columns instead of 33)
#     Line #351 (got 32 columns instead of 33)
#     Line #352 (got 32 columns instead of 33)
#     Line #353 (got 32 columns instead of 33)
#     Line #354 (got 32 columns instead of 33)
#     Line #355 (got 32 columns instead of 33)
#     Line #356 (got 32 columns instead of 33)
#     Line #357 (got 32 columns instead of 33)
#     Line #358 (got 32 columns instead of 33)
#     Line #359 (got 32 columns instead of 33)
#     Line #360 (got 32 columns instead of 33)
#     Line #361 (got 32 columns instead of 33)
#     Line #362 (got 32 columns instead of 33)
#     Line #363 (got 32 columns instead of 33)
#     Line #364 (got 32 columns instead of 33)
#     Line #365 (got 32 columns instead of 33)
#     Line #366 (got 32 columns instead of 33)
#     Line #367 (got 32 columns instead of 33)
#     Line #368 (got 32 columns instead of 33)
#     Line #369 (got 32 columns instead of 33)
#     Line #370 (got 32 columns instead of 33)
#     Line #371 (got 32 columns instead of 33)
#     Line #372 (got 32 columns instead of 33)
#     Line #373 (got 32 columns instead of 33)
#     Line #374 (got 32 columns instead of 33)
#     Line #375 (got 32 columns instead of 33)
#     Line #376 (got 32 columns instead of 33)
#     Line #377 (got 32 columns instead of 33)
#     Line #378 (got 32 columns instead of 33)
#     Line #379 (got 32 columns instead of 33)
#     Line #380 (got 32 columns instead of 33)
#     Line #381 (got 32 columns instead of 33)
#     Line #382 (got 32 columns instead of 33)
#     Line #383 (got 32 columns instead of 33)
#     Line #384 (got 32 columns instead of 33)
#     Line #385 (got 32 columns instead of 33)
#     Line #386 (got 32 columns instead of 33)
#     Line #387 (got 32 columns instead of 33)
#     Line #388 (got 32 columns instead of 33)
#     Line #389 (got 32 columns instead of 33)
#     Line #390 (got 32 columns instead of 33)
#     Line #391 (got 32 columns instead of 33)
#     Line #392 (got 32 columns instead of 33)
#     Line #393 (got 32 columns instead of 33)
#     Line #394 (got 32 columns instead of 33)
#     Line #395 (got 32 columns instead of 33)
#     Line #396 (got 32 columns instead of 33)
#     Line #397 (got 32 columns instead of 33)
#     Line #398 (got 32 columns instead of 33)
#     Line #399 (got 32 columns instead of 33)
#     Line #400 (got 32 columns instead of 33)
#     Line #401 (got 32 columns instead of 33)
#     Line #402 (got 32 columns instead of 33)
#     Line #403 (got 32 columns instead of 33)
#     Line #404 (got 32 columns instead of 33)
#     Line #405 (got 32 columns instead of 33)
#     Line #406 (got 32 columns instead of 33)
#     Line #407 (got 32 columns instead of 33)
#     Line #408 (got 32 columns instead of 33)
#     Line #409 (got 32 columns instead of 33)
#     Line #410 (got 32 columns instead of 33)
#     Line #411 (got 32 columns instead of 33)
#     Line #412 (got 32 columns instead of 33)
#     Line #413 (got 32 columns instead of 33)
#     Line #414 (got 32 columns instead of 33)
#     Line #415 (got 32 columns instead of 33)
#     Line #416 (got 32 columns instead of 33)
#     Line #417 (got 32 columns instead of 33)
#     Line #418 (got 32 columns instead of 33)
#     Line #419 (got 32 columns instead of 33)
#     Line #420 (got 32 columns instead of 33)
#     Line #421 (got 32 columns instead of 33)
#     Line #422 (got 32 columns instead of 33)
#     Line #423 (got 32 columns instead of 33)
#     Line #424 (got 32 columns instead of 33)
#     Line #425 (got 32 columns instead of 33)
#     Line #426 (got 32 columns instead of 33)
#     Line #427 (got 32 columns instead of 33)
#     Line #428 (got 32 columns instead of 33)
#     Line #429 (got 32 columns instead of 33)
#     Line #430 (got 32 columns instead of 33)
#     Line #431 (got 32 columns instead of 33)
#     Line #432 (got 32 columns instead of 33)
#     Line #433 (got 32 columns instead of 33)
#     Line #434 (got 32 columns instead of 33)
#     Line #435 (got 32 columns instead of 33)
#     Line #436 (got 32 columns instead of 33)
#     Line #437 (got 32 columns instead of 33)
#     Line #438 (got 32 columns instead of 33)
#     Line #439 (got 32 columns instead of 33)
#     Line #440 (got 32 columns instead of 33)
#     Line #441 (got 32 columns instead of 33)
#     Line #442 (got 32 columns instead of 33)
#     Line #443 (got 32 columns instead of 33)
#     Line #444 (got 32 columns instead of 33)
#     Line #445 (got 32 columns instead of 33)
#     Line #446 (got 32 columns instead of 33)
#     Line #447 (got 32 columns instead of 33)
#     Line #448 (got 32 columns instead of 33)
#     Line #449 (got 32 columns instead of 33)
#     Line #450 (got 32 columns instead of 33)
#     Line #451 (got 32 columns instead of 33)
#     Line #452 (got 32 columns instead of 33)
#     Line #453 (got 32 columns instead of 33)
#     Line #454 (got 32 columns instead of 33)
#     Line #455 (got 32 columns instead of 33)
#     Line #456 (got 32 columns instead of 33)
#     Line #457 (got 32 columns instead of 33)
#     Line #458 (got 32 columns instead of 33)
#     Line #459 (got 32 columns instead of 33)
#     Line #460 (got 32 columns instead of 33)
#     Line #461 (got 32 columns instead of 33)
#     Line #462 (got 32 columns instead of 33)
#     Line #463 (got 32 columns instead of 33)
#     Line #464 (got 32 columns instead of 33)
#     Line #465 (got 32 columns instead of 33)
#     Line #466 (got 32 columns instead of 33)
#     Line #467 (got 32 columns instead of 33)
#     Line #468 (got 32 columns instead of 33)
#     Line #469 (got 32 columns instead of 33)
#     Line #470 (got 32 columns instead of 33)
#     Line #471 (got 32 columns instead of 33)
#     Line #472 (got 32 columns instead of 33)
#     Line #473 (got 32 columns instead of 33)
#     Line #474 (got 32 columns instead of 33)
#     Line #475 (got 32 columns instead of 33)
#     Line #476 (got 32 columns instead of 33)
#     Line #477 (got 32 columns instead of 33)
#     Line #478 (got 32 columns instead of 33)
#     Line #479 (got 32 columns instead of 33)
#     Line #480 (got 32 columns instead of 33)
#     Line #481 (got 32 columns instead of 33)
#     Line #482 (got 32 columns instead of 33)
#     Line #483 (got 32 columns instead of 33)
#     Line #484 (got 32 columns instead of 33)
#     Line #485 (got 32 columns instead of 33)
#     Line #486 (got 32 columns instead of 33)
#     Line #487 (got 32 columns instead of 33)
#     Line #488 (got 32 columns instead of 33)
#     Line #489 (got 32 columns instead of 33)
#     Line #490 (got 32 columns instead of 33)
#     Line #491 (got 32 columns instead of 33)
#     Line #492 (got 32 columns instead of 33)
#     Line #493 (got 32 columns instead of 33)
#     Line #494 (got 32 columns instead of 33)
#     Line #495 (got 32 columns instead of 33)
#     Line #496 (got 32 columns instead of 33)
#     Line #497 (got 32 columns instead of 33)
#     Line #498 (got 32 columns instead of 33)
#     Line #499 (got 32 columns instead of 33)
#     Line #500 (got 32 columns instead of 33)
#     Line #501 (got 32 columns instead of 33)
#     Line #502 (got 32 columns instead of 33)
#     Line #503 (got 32 columns instead of 33)
#     Line #504 (got 32 columns instead of 33)
#     Line #505 (got 32 columns instead of 33)
#     Line #506 (got 32 columns instead of 33)
#     Line #507 (got 32 columns instead of 33)
#     Line #508 (got 32 columns instead of 33)
#     Line #509 (got 32 columns instead of 33)
#     Line #510 (got 32 columns instead of 33)
#     Line #511 (got 32 columns instead of 33)
#     Line #512 (got 32 columns instead of 33)
#     Line #513 (got 32 columns instead of 33)
#     Line #514 (got 32 columns instead of 33)
#     Line #515 (got 32 columns instead of 33)
#     Line #516 (got 32 columns instead of 33)
#     Line #517 (got 32 columns instead of 33)
#     Line #518 (got 32 columns instead of 33)
#     Line #519 (got 32 columns instead of 33)
#     Line #520 (got 32 columns instead of 33)
#     Line #521 (got 32 columns instead of 33)
#     Line #522 (got 32 columns instead of 33)
#     Line #523 (got 32 columns instead of 33)
#     Line #524 (got 32 columns instead of 33)
#     Line #525 (got 32 columns instead of 33)
#     Line #526 (got 32 columns instead of 33)
#     Line #527 (got 32 columns instead of 33)
#     Line #528 (got 32 columns instead of 33)
#     Line #529 (got 32 columns instead of 33)
#     Line #530 (got 32 columns instead of 33)
#     Line #531 (got 32 columns instead of 33)
#     Line #532 (got 32 columns instead of 33)
#     Line #533 (got 32 columns instead of 33)
#     Line #534 (got 32 columns instead of 33)
#     Line #535 (got 32 columns instead of 33)
#     Line #536 (got 32 columns instead of 33)
#     Line #537 (got 32 columns instead of 33)
#     Line #538 (got 32 columns instead of 33)
#     Line #539 (got 32 columns instead of 33)
#     Line #540 (got 32 columns instead of 33)
#     Line #541 (got 32 columns instead of 33)
#     Line #542 (got 32 columns instead of 33)
#     Line #543 (got 32 columns instead of 33)
#     Line #544 (got 32 columns instead of 33)
#     Line #545 (got 32 columns instead of 33)
#     Line #546 (got 32 columns instead of 33)
#     Line #547 (got 32 columns instead of 33)
#     Line #548 (got 32 columns instead of 33)
#     Line #549 (got 32 columns instead of 33)
#     Line #550 (got 32 columns instead of 33)
#     Line #551 (got 32 columns instead of 33)
#     Line #552 (got 32 columns instead of 33)
#     Line #553 (got 32 columns instead of 33)
#     Line #554 (got 32 columns instead of 33)
#     Line #555 (got 32 columns instead of 33)
#     Line #556 (got 32 columns instead of 33)
#     Line #557 (got 32 columns instead of 33)
#     Line #558 (got 32 columns instead of 33)
#     Line #559 (got 32 columns instead of 33)
#     Line #560 (got 32 columns instead of 33)
#     Line #561 (got 32 columns instead of 33)
#     Line #562 (got 32 columns instead of 33)
#     Line #563 (got 32 columns instead of 33)
#     Line #564 (got 32 columns instead of 33)
#     Line #565 (got 32 columns instead of 33)
#     Line #566 (got 32 columns instead of 33)
#     Line #567 (got 32 columns instead of 33)
#     Line #568 (got 32 columns instead of 33)
#     Line #569 (got 32 columns instead of 33)
#     Line #570 (got 32 columns instead of 33)
